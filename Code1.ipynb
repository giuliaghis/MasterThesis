# %%
# Import relevant libraries.
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import the dataset.
dataset = pd.read_csv ('Thesis_Survey_Students_July_9.csv')

# %%
# Have a quick look of the dataset.
dataset.head()
# Out:
#                                            StartDate  \
# 0                                         Start Date
# 1  {"ImportId":"startDate","timeZone":"Europe/Ber...
# 2                                2024-07-01 09:25:42
# 3                                2024-07-01 10:09:13
# 4                                2024-07-01 10:43:46
#
#                                              EndDate                 Status  \
# 0                                           End Date          Response Type
# 1  {"ImportId":"endDate","timeZone":"Europe/Berlin"}  {"ImportId":"status"}
# 2                                2024-07-01 10:14:40             IP Address
# 3                                2024-07-01 10:25:53             IP Address
# 4                                2024-07-01 10:54:59             IP Address
#
#                   Progress    Duration (in seconds)                 Finished  \
# 0                 Progress    Duration (in seconds)                 Finished
# 1  {"ImportId":"progress"}  {"ImportId":"duration"}  {"ImportId":"finished"}
# 2                      100                     2937                     True
# 3                      100                     1000                     True
# 4                      100                      673                     True
#
#                                         RecordedDate  \
# 0                                      Recorded Date
# 1  {"ImportId":"recordedDate","timeZone":"Europe/...
# 2                                2024-07-01 10:14:40
# 3                                2024-07-01 10:25:54
# 4                                2024-07-01 10:55:00
#
#                  ResponseId                 DistributionChannel  \
# 0               Response ID                Distribution Channel
# 1  {"ImportId":"_recordId"}  {"ImportId":"distributionChannel"}
# 2         R_8TL5KyUekYXgw8A                           anonymous
# 3         R_8iL1LO6WligSYs2                           anonymous
# 4         R_8pgLr7rRK1oJDyG                           anonymous
#
#                   UserLanguage  ...                University  \
# 0                User Language  ...   Where are you studying?
# 1  {"ImportId":"userLanguage"}  ...      {"ImportId":"QID30"}
# 2                           IT  ...  Other Italian university
# 3                           EN  ...          LUISS university
# 4                           IT  ...  Other Italian university
#
#                       Academic field  \
# 0       What is your academic field?
# 1               {"ImportId":"QID31"}
# 2  Economic and Statistical Sciences
# 3  Mathematical and Computer Science
# 4      Political and Social Sciences
#
#                                             Thoughts  \
# 0  What are your thoughts on the future of educat...
# 1                          {"ImportId":"QID33_TEXT"}
# 2  Se integrata con giudizio, può diventare uno s...
# 3   It is important to understand how to use it t...
# 4  Penso che sarà uno strumento molto utilizzato,...
#
#                   Q_AmbiguousTextPresent  \
# 0                 Q_AmbiguousTextPresent
# 1  {"ImportId":"Q_AmbiguousTextPresent"}
# 2                                      0
# 3                                      0
# 4                                      0
#
#                   Q_AmbiguousTextQuestions  \
# 0                 Q_AmbiguousTextQuestions
# 1  {"ImportId":"Q_AmbiguousTextQuestions"}
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#                   Q_StraightliningCount  \
# 0                 Q_StraightliningCount
# 1  {"ImportId":"Q_StraightliningCount"}
# 2                                     0
# 3                                     0
# 4                                     0
#
#                   Q_StraightliningPercentage  \
# 0                 Q_StraightliningPercentage
# 1  {"ImportId":"Q_StraightliningPercentage"}
# 2                                          0
# 3                                          0
# 4                                          0
#
#                   Q_StraightliningQuestions  \
# 0                 Q_StraightliningQuestions
# 1  {"ImportId":"Q_StraightliningQuestions"}
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#                   Q_UnansweredPercentage                 Q_UnansweredQuestions
# 0                 Q_UnansweredPercentage                 Q_UnansweredQuestions
# 1  {"ImportId":"Q_UnansweredPercentage"}  {"ImportId":"Q_UnansweredQuestions"}
# 2                                      0                                   NaN
# 3                                      0                                   NaN
# 4                                      0                                   NaN
#
# [5 rows x 107 columns]

# %%
dataset.columns.tolist()
# Out:
# ['StartDate',
#  'EndDate',
#  'Status',
#  'Progress',
#  'Duration (in seconds)',
#  'Finished',
#  'RecordedDate',
#  'ResponseId',
#  'DistributionChannel',
#  'UserLanguage',
#  'Q_RecaptchaScore',
#  'Familiarity_1',
#  'Openness_1',
#  'Comfort_1',
#  'Study method_1',
#  'Study method_2',
#  'Study method_3',
#  'Study method_4',
#  'Study method_5',
#  'Study method_6',
#  'Study method_7',
#  'Study method_7_TEXT',
#  'Preference_1',
#  'Human vs AI_1',
#  'Criteria Professors_1',
#  'Criteria Professors_2',
#  'Criteria Professors_3',
#  'Criteria Professors_4',
#  'Criteria Professors_5',
#  'Criteria Professors_6',
#  'Criteria Professors_7',
#  'Criteria Professors_8',
#  'Criteria Professors_9',
#  'Criteria Professors_10',
#  'Criteria Professors_10_TEXT',
#  'Frequency_1',
#  'Frequency_2',
#  'Frequency_3',
#  'Frequency_4',
#  'Frequency_5',
#  'Frequency_6',
#  'Frequency_7',
#  'Frequency_7_TEXT',
#  'Likelihood_1',
#  'Likelihood_2',
#  'Likelihood_3',
#  'Likelihood_4',
#  'Likelihood_5',
#  'Concern_1',
#  'Inputs',
#  'Agreement options_1',
#  'Agreement options_2',
#  'Agreement options_3',
#  'Agreement options_4',
#  'Agreement options_5',
#  'Agreement options_6',
#  'Agreement options_7',
#  'Impact_1',
#  'Performance_1',
#  'Grade',
#  'Satisfaction_1',
#  'Comparison_1',
#  'Comparison_2',
#  'Comparison_3',
#  'Comparison_4',
#  'Comparison_5',
#  'Comparison_6',
#  'Comparison_7',
#  'Benefits_1',
#  'Benefits_2',
#  'Benefits_3',
#  'Benefits_4',
#  'Benefits_5',
#  'Benefits_6',
#  'Benefits_7',
#  'Benefits_8',
#  'Benefits_9',
#  'Benefits_10',
#  'Benefits_11',
#  'Benefits_11_TEXT',
#  'Concerns_1',
#  'Concerns_2',
#  'Concerns_3',
#  'Concerns_4',
#  'Concerns_5',
#  'Concerns_6',
#  'Concerns_7',
#  'Concerns_8',
#  'Concerns_9',
#  'Concerns_10',
#  'Concerns_11',
#  'Concerns_12',
#  'Concerns_12_TEXT',
#  'Age',
#  'Gender',
#  'Home country',
#  'Level of education',
#  'University',
#  'Academic field',
#  'Thoughts',
#  'Q_AmbiguousTextPresent',
#  'Q_AmbiguousTextQuestions',
#  'Q_StraightliningCount',
#  'Q_StraightliningPercentage',
#  'Q_StraightliningQuestions',
#  'Q_UnansweredPercentage',
#  'Q_UnansweredQuestions']

# %%
# Create a new dataset where the columns that are not relevant for the analysis are dropped.
df = dataset.drop(columns=['StartDate','EndDate','Status','Progress','Duration (in seconds)','Finished','RecordedDate','ResponseId','DistributionChannel','UserLanguage','Q_RecaptchaScore','Q_AmbiguousTextPresent','Q_AmbiguousTextQuestions','Q_StraightliningCount','Q_StraightliningPercentage','Q_StraightliningQuestions','Q_UnansweredPercentage','Q_UnansweredQuestions'])

# %%
df.head()
# Out:
#                                        Familiarity_1  \
# 0  How familiar are you with Generative Artificia...
# 1                              {"ImportId":"QID4_1"}
# 2                                                 50
# 3                                                 85
# 4                                                 60
#
#                                           Openness_1  \
# 0  What is your overall attitude towards using te...
# 1                              {"ImportId":"QID9_1"}
# 2                                                 75
# 3                                                 90
# 4                                                100
#
#                                            Comfort_1  \
# 0  How comfortable do you feel using digital tool...
# 1                             {"ImportId":"QID10_1"}
# 2                                                 75
# 3                                                 90
# 4                                                100
#
#                                       Study method_1  \
# 0  What is your study method?\nPlease, drag and d...
# 1                             {"ImportId":"QID11_1"}
# 2                                                  2
# 3                                                  1
# 4                                                  2
#
#                                       Study method_2  \
# 0  What is your study method?\nPlease, drag and d...
# 1                             {"ImportId":"QID11_2"}
# 2                                                  3
# 3                                                  4
# 4                                                  3
#
#                                       Study method_3  \
# 0  What is your study method?\nPlease, drag and d...
# 1                             {"ImportId":"QID11_3"}
# 2                                                  4
# 3                                                  6
# 4                                                  6
#
#                                       Study method_4  \
# 0  What is your study method?\nPlease, drag and d...
# 1                             {"ImportId":"QID11_4"}
# 2                                                  1
# 3                                                  3
# 4                                                  1
#
#                                       Study method_5  \
# 0  What is your study method?\nPlease, drag and d...
# 1                             {"ImportId":"QID11_5"}
# 2                                                  5
# 3                                                  2
# 4                                                  4
#
#                                       Study method_6  \
# 0  What is your study method?\nPlease, drag and d...
# 1                             {"ImportId":"QID11_6"}
# 2                                                  6
# 3                                                  5
# 4                                                  5
#
#                                       Study method_7  ...  \
# 0  What is your study method?\nPlease, drag and d...  ...
# 1                             {"ImportId":"QID11_7"}  ...
# 2                                                  7  ...
# 3                                                  7  ...
# 4                                                  7  ...
#
#                                          Concerns_11  \
# 0  What potential concerns do you have about usin...
# 1               {"ImportId":"QID26","choiceId":"11"}
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                          Concerns_12  \
# 0  What potential concerns do you have about usin...
# 1               {"ImportId":"QID26","choiceId":"12"}
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                     Concerns_12_TEXT                   Age  \
# 0  What potential concerns do you have about usin...      How old are you?
# 1                       {"ImportId":"QID26_12_TEXT"}  {"ImportId":"QID27"}
# 2                                                NaN                 23-26
# 3                                                NaN                 23-26
# 4                                                NaN                 23-26
#
#                              Gender  \
# 0  How would you identify yourself?
# 1              {"ImportId":"QID28"}
# 2                            Female
# 3                            Female
# 4                            Female
#
#                                         Home country  \
# 0  Where are you from? Please, specify your home ...
# 1                          {"ImportId":"QID29_TEXT"}
# 2                                             Italia
# 3                                              ITALY
# 4                                            Italia
#
#                                   Level of education  \
# 0  What level of education are you currently purs...
# 1                               {"ImportId":"QID32"}
# 2                                    Master's Degree
# 3                                    Master's Degree
# 4                                  Bachelor's Degree
#
#                  University                     Academic field  \
# 0   Where are you studying?       What is your academic field?
# 1      {"ImportId":"QID30"}               {"ImportId":"QID31"}
# 2  Other Italian university  Economic and Statistical Sciences
# 3          LUISS university  Mathematical and Computer Science
# 4  Other Italian university      Political and Social Sciences
#
#                                             Thoughts
# 0  What are your thoughts on the future of educat...
# 1                          {"ImportId":"QID33_TEXT"}
# 2  Se integrata con giudizio, può diventare uno s...
# 3   It is important to understand how to use it t...
# 4  Penso che sarà uno strumento molto utilizzato,...
#
# [5 rows x 89 columns]

# %%
# Drop rows that are not relevant for the analysis.
df.drop(index=[0,1], inplace=True)

# %%
# Reset the indexes.
df.reset_index(drop=True, inplace=True)

# %%
df.shape
# Out:
# (70, 89)

# %%
dataset.shape
# Out:
# (72, 107)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 89 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Familiarity_1                59 non-null     object
#  1   Openness_1                   59 non-null     object
#  2   Comfort_1                    59 non-null     object
#  3   Study method_1               57 non-null     object
#  4   Study method_2               57 non-null     object
#  5   Study method_3               57 non-null     object
#  6   Study method_4               57 non-null     object
#  7   Study method_5               57 non-null     object
#  8   Study method_6               57 non-null     object
#  9   Study method_7               57 non-null     object
#  10  Study method_7_TEXT          1 non-null      object
#  11  Preference_1                 57 non-null     object
#  12  Human vs AI_1                57 non-null     object
#  13  Criteria Professors_1        56 non-null     object
#  14  Criteria Professors_2        56 non-null     object
#  15  Criteria Professors_3        56 non-null     object
#  16  Criteria Professors_4        56 non-null     object
#  17  Criteria Professors_5        56 non-null     object
#  18  Criteria Professors_6        56 non-null     object
#  19  Criteria Professors_7        56 non-null     object
#  20  Criteria Professors_8        56 non-null     object
#  21  Criteria Professors_9        56 non-null     object
#  22  Criteria Professors_10       56 non-null     object
#  23  Criteria Professors_10_TEXT  0 non-null      object
#  24  Frequency_1                  50 non-null     object
#  25  Frequency_2                  53 non-null     object
#  26  Frequency_3                  51 non-null     object
#  27  Frequency_4                  51 non-null     object
#  28  Frequency_5                  51 non-null     object
#  29  Frequency_6                  45 non-null     object
#  30  Frequency_7                  22 non-null     object
#  31  Frequency_7_TEXT             2 non-null      object
#  32  Likelihood_1                 53 non-null     object
#  33  Likelihood_2                 53 non-null     object
#  34  Likelihood_3                 53 non-null     object
#  35  Likelihood_4                 53 non-null     object
#  36  Likelihood_5                 53 non-null     object
#  37  Concern_1                    53 non-null     object
#  38  Inputs                       53 non-null     object
#  39  Agreement options_1          52 non-null     object
#  40  Agreement options_2          52 non-null     object
#  41  Agreement options_3          52 non-null     object
#  42  Agreement options_4          52 non-null     object
#  43  Agreement options_5          52 non-null     object
#  44  Agreement options_6          52 non-null     object
#  45  Agreement options_7          52 non-null     object
#  46  Impact_1                     51 non-null     object
#  47  Performance_1                51 non-null     object
#  48  Grade                        51 non-null     object
#  49  Satisfaction_1               51 non-null     object
#  50  Comparison_1                 51 non-null     object
#  51  Comparison_2                 51 non-null     object
#  52  Comparison_3                 51 non-null     object
#  53  Comparison_4                 51 non-null     object
#  54  Comparison_5                 51 non-null     object
#  55  Comparison_6                 51 non-null     object
#  56  Comparison_7                 51 non-null     object
#  57  Benefits_1                   24 non-null     object
#  58  Benefits_2                   44 non-null     object
#  59  Benefits_3                   16 non-null     object
#  60  Benefits_4                   33 non-null     object
#  61  Benefits_5                   21 non-null     object
#  62  Benefits_6                   23 non-null     object
#  63  Benefits_7                   13 non-null     object
#  64  Benefits_8                   29 non-null     object
#  65  Benefits_9                   13 non-null     object
#  66  Benefits_10                  14 non-null     object
#  67  Benefits_11                  0 non-null      object
#  68  Benefits_11_TEXT             0 non-null      object
#  69  Concerns_1                   34 non-null     object
#  70  Concerns_2                   21 non-null     object
#  71  Concerns_3                   30 non-null     object
#  72  Concerns_4                   20 non-null     object
#  73  Concerns_5                   10 non-null     object
#  74  Concerns_6                   34 non-null     object
#  75  Concerns_7                   27 non-null     object
#  76  Concerns_8                   28 non-null     object
#  77  Concerns_9                   28 non-null     object
#  78  Concerns_10                  30 non-null     object
#  79  Concerns_11                  11 non-null     object
#  80  Concerns_12                  0 non-null      object
#  81  Concerns_12_TEXT             0 non-null      object
#  82  Age                          51 non-null     object
#  83  Gender                       51 non-null     object
#  84  Home country                 51 non-null     object
#  85  Level of education           51 non-null     object
#  86  University                   51 non-null     object
#  87  Academic field               51 non-null     object
#  88  Thoughts                     51 non-null     object
# dtypes: object(89)
# memory usage: 48.8+ KB

# %%
# Drop rows that have null values in the last mandatory question, meaning respondents have opened the survey but not finished it.
df.dropna(subset=['Thoughts'], inplace=True)

# %%
df.shape
# Out:
# (51, 89)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, 0 to 52
# Data columns (total 89 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Familiarity_1                51 non-null     object
#  1   Openness_1                   51 non-null     object
#  2   Comfort_1                    51 non-null     object
#  3   Study method_1               51 non-null     object
#  4   Study method_2               51 non-null     object
#  5   Study method_3               51 non-null     object
#  6   Study method_4               51 non-null     object
#  7   Study method_5               51 non-null     object
#  8   Study method_6               51 non-null     object
#  9   Study method_7               51 non-null     object
#  10  Study method_7_TEXT          1 non-null      object
#  11  Preference_1                 51 non-null     object
#  12  Human vs AI_1                51 non-null     object
#  13  Criteria Professors_1        51 non-null     object
#  14  Criteria Professors_2        51 non-null     object
#  15  Criteria Professors_3        51 non-null     object
#  16  Criteria Professors_4        51 non-null     object
#  17  Criteria Professors_5        51 non-null     object
#  18  Criteria Professors_6        51 non-null     object
#  19  Criteria Professors_7        51 non-null     object
#  20  Criteria Professors_8        51 non-null     object
#  21  Criteria Professors_9        51 non-null     object
#  22  Criteria Professors_10       51 non-null     object
#  23  Criteria Professors_10_TEXT  0 non-null      object
#  24  Frequency_1                  47 non-null     object
#  25  Frequency_2                  49 non-null     object
#  26  Frequency_3                  47 non-null     object
#  27  Frequency_4                  47 non-null     object
#  28  Frequency_5                  47 non-null     object
#  29  Frequency_6                  43 non-null     object
#  30  Frequency_7                  22 non-null     object
#  31  Frequency_7_TEXT             2 non-null      object
#  32  Likelihood_1                 51 non-null     object
#  33  Likelihood_2                 51 non-null     object
#  34  Likelihood_3                 51 non-null     object
#  35  Likelihood_4                 51 non-null     object
#  36  Likelihood_5                 51 non-null     object
#  37  Concern_1                    51 non-null     object
#  38  Inputs                       51 non-null     object
#  39  Agreement options_1          51 non-null     object
#  40  Agreement options_2          51 non-null     object
#  41  Agreement options_3          51 non-null     object
#  42  Agreement options_4          51 non-null     object
#  43  Agreement options_5          51 non-null     object
#  44  Agreement options_6          51 non-null     object
#  45  Agreement options_7          51 non-null     object
#  46  Impact_1                     51 non-null     object
#  47  Performance_1                51 non-null     object
#  48  Grade                        51 non-null     object
#  49  Satisfaction_1               51 non-null     object
#  50  Comparison_1                 51 non-null     object
#  51  Comparison_2                 51 non-null     object
#  52  Comparison_3                 51 non-null     object
#  53  Comparison_4                 51 non-null     object
#  54  Comparison_5                 51 non-null     object
#  55  Comparison_6                 51 non-null     object
#  56  Comparison_7                 51 non-null     object
#  57  Benefits_1                   24 non-null     object
#  58  Benefits_2                   44 non-null     object
#  59  Benefits_3                   16 non-null     object
#  60  Benefits_4                   33 non-null     object
#  61  Benefits_5                   21 non-null     object
#  62  Benefits_6                   23 non-null     object
#  63  Benefits_7                   13 non-null     object
#  64  Benefits_8                   29 non-null     object
#  65  Benefits_9                   13 non-null     object
#  66  Benefits_10                  14 non-null     object
#  67  Benefits_11                  0 non-null      object
#  68  Benefits_11_TEXT             0 non-null      object
#  69  Concerns_1                   34 non-null     object
#  70  Concerns_2                   21 non-null     object
#  71  Concerns_3                   30 non-null     object
#  72  Concerns_4                   20 non-null     object
#  73  Concerns_5                   10 non-null     object
#  74  Concerns_6                   34 non-null     object
#  75  Concerns_7                   27 non-null     object
#  76  Concerns_8                   28 non-null     object
#  77  Concerns_9                   28 non-null     object
#  78  Concerns_10                  30 non-null     object
#  79  Concerns_11                  11 non-null     object
#  80  Concerns_12                  0 non-null      object
#  81  Concerns_12_TEXT             0 non-null      object
#  82  Age                          51 non-null     object
#  83  Gender                       51 non-null     object
#  84  Home country                 51 non-null     object
#  85  Level of education           51 non-null     object
#  86  University                   51 non-null     object
#  87  Academic field               51 non-null     object
#  88  Thoughts                     51 non-null     object
# dtypes: object(89)
# memory usage: 35.9+ KB

# %%
df
# Out:
#    Familiarity_1 Openness_1 Comfort_1 Study method_1 Study method_2  \
# 0             50         75        75              2              3
# 1             85         90        90              1              4
# 2             60        100       100              2              3
# 3             30         70        70              2              1
# 4            100         62        76              1              3
# 5             61         90        80              2              3
# 6             80         81        75              2              3
# 7             80         35        65              6              1
# 8            100         74       100              2              5
# 9             57         43        73              1              2
# 10           100        100       100              1              2
# 11            95         90       100              2              6
# 12            80         50       100              2              3
# 13            70         80        70              5              2
# 14            70         90       100              2              3
# 15            60         80        90              3              2
# 16            70         90       100              2              3
# 17            80         71        60              2              5
# 18           100        100       100              2              3
# 19            65        100       100              2              4
# 20           100        100       100              2              3
# 21            86         75        75              2              3
# 22             0         85        90              1              2
# 23            55        100        97              2              3
# 24            55         72        77              1              2
# 25            62         93        91              2              4
# 26            50         60        75              2              3
# 27            50         70        60              2              4
# 29            70         70       100              5              2
# 30            90         60        70              3              4
# 31            71        100       100              2              3
# 32            75        100       100              2              3
# 33            60         90        90              3              1
# 34            70         65        75              4              3
# 35            85         65        67              1              5
# 36            80         50        75              2              3
# 37            45         90        70              3              2
# 38            80        100       100              6              2
# 39            50        100       100              2              6
# 40            27         91        92              1              5
# 41            56         85        85              1              3
# 42            90         73        77              1              2
# 43            89        100       100              2              3
# 44           100         57        65              1              2
# 45            70         87        81              1              2
# 46           100         90       100              2              3
# 48            62         28        72              1              2
# 49            29         80       100              3              1
# 50            80         50        60              3              1
# 51            56         75        62              2              4
# 52            29         57        67              1              2
#
#    Study method_3 Study method_4 Study method_5 Study method_6 Study method_7  \
# 0               4              1              5              6              7
# 1               6              3              2              5              7
# 2               6              1              4              5              7
# 3               5              3              4              7              6
# 4               4              5              2              6              7
# 5               6              1              4              5              7
# 6               4              1              5              6              7
# 7               2              3              4              7              5
# 8               6              1              3              4              7
# 9               4              5              6              3              7
# 10              3              4              6              5              7
# 11              5              1              3              4              7
# 12              6              1              4              5              7
# 13              6              1              3              4              7
# 14              5              1              4              6              7
# 15              5              1              4              6              7
# 16              1              6              5              4              7
# 17              4              1              3              6              7
# 18              4              1              5              6              7
# 19              5              1              3              6              7
# 20              5              1              4              6              7
# 21              4              1              5              6              7
# 22              3              4              5              7              6
# 23              5              1              4              7              6
# 24              3              5              4              6              7
# 25              5              3              1              6              7
# 26              4              1              5              6              7
# 27              5              3              1              6              7
# 29              1              3              4              6              7
# 30              1              2              5              6              7
# 31              5              1              4              6              7
# 32              4              1              5              6              7
# 33              6              4              5              2              7
# 34              6              2              5              1              7
# 35              2              3              6              4              7
# 36              4              6              5              1              7
# 37              4              5              6              1              7
# 38              3              1              4              5              7
# 39              3              1              4              5              7
# 40              3              2              4              6              7
# 41              4              2              5              6              7
# 42              5              3              4              6              7
# 43              6              1              4              5              7
# 44              4              5              3              6              7
# 45              3              5              6              4              7
# 46              5              1              4              6              7
# 48              6              3              4              5              7
# 49              6              4              2              5              7
# 50              5              6              2              4              7
# 51              5              1              3              6              7
# 52              3              4              5              6              7
#
#     ...       Concerns_11 Concerns_12 Concerns_12_TEXT    Age  Gender  \
# 0   ...               NaN         NaN              NaN  23-26  Female
# 1   ...               NaN         NaN              NaN  23-26  Female
# 2   ...               NaN         NaN              NaN  23-26  Female
# 3   ...               NaN         NaN              NaN  23-26    Male
# 4   ...  Technical issues         NaN              NaN  23-26  Female
# 5   ...               NaN         NaN              NaN  23-26  Female
# 6   ...  Technical issues         NaN              NaN  23-26  Female
# 7   ...               NaN         NaN              NaN  23-26    Male
# 8   ...               NaN         NaN              NaN  23-26    Male
# 9   ...               NaN         NaN              NaN  18-22    Male
# 10  ...               NaN         NaN              NaN  23-26  Female
# 11  ...               NaN         NaN              NaN  23-26  Female
# 12  ...               NaN         NaN              NaN  23-26  Female
# 13  ...               NaN         NaN              NaN  27-30    Male
# 14  ...  Technical issues         NaN              NaN  18-22    Male
# 15  ...               NaN         NaN              NaN  23-26  Female
# 16  ...               NaN         NaN              NaN  23-26  Female
# 17  ...               NaN         NaN              NaN  23-26  Female
# 18  ...               NaN         NaN              NaN  23-26  Female
# 19  ...               NaN         NaN              NaN  23-26    Male
# 20  ...               NaN         NaN              NaN  23-26  Female
# 21  ...               NaN         NaN              NaN  23-26  Female
# 22  ...               NaN         NaN              NaN  23-26    Male
# 23  ...               NaN         NaN              NaN  27-30    Male
# 24  ...               NaN         NaN              NaN  23-26  Female
# 25  ...               NaN         NaN              NaN  23-26  Female
# 26  ...  Technical issues         NaN              NaN  23-26  Female
# 27  ...               NaN         NaN              NaN  23-26  Female
# 29  ...               NaN         NaN              NaN  18-22    Male
# 30  ...  Technical issues         NaN              NaN  27-30  Female
# 31  ...               NaN         NaN              NaN  18-22  Female
# 32  ...  Technical issues         NaN              NaN  18-22  Female
# 33  ...               NaN         NaN              NaN  18-22    Male
# 34  ...  Technical issues         NaN              NaN  18-22  Female
# 35  ...               NaN         NaN              NaN  23-26  Female
# 36  ...               NaN         NaN              NaN  23-26  Female
# 37  ...               NaN         NaN              NaN  18-22  Female
# 38  ...  Technical issues         NaN              NaN  18-22    Male
# 39  ...               NaN         NaN              NaN  18-22  Female
# 40  ...               NaN         NaN              NaN  18-22  Female
# 41  ...  Technical issues         NaN              NaN  18-22  Female
# 42  ...               NaN         NaN              NaN  23-26  Female
# 43  ...               NaN         NaN              NaN  18-22  Female
# 44  ...               NaN         NaN              NaN  23-26  Female
# 45  ...  Technical issues         NaN              NaN  23-26  Female
# 46  ...  Technical issues         NaN              NaN  23-26    Male
# 48  ...               NaN         NaN              NaN  23-26    Male
# 49  ...               NaN         NaN              NaN  18-22    Male
# 50  ...               NaN         NaN              NaN  18-22  Female
# 51  ...               NaN         NaN              NaN  18-22    Male
# 52  ...               NaN         NaN              NaN  18-22    Male
#
#     Home country Level of education                        University  \
# 0         Italia    Master's Degree          Other Italian university
# 1          ITALY    Master's Degree                  LUISS university
# 2        Italia   Bachelor's Degree          Other Italian university
# 3        Italia     Master's Degree          Other Italian university
# 4         Italia    Master's Degree                  LUISS university
# 5         Italia    Master's Degree                  LUISS university
# 6         Italia    Master's Degree          Other Italian university
# 7         Italia    Master's Degree          Other Italian university
# 8        Italia     Master's Degree          Other Italian university
# 9           Roma  Bachelor's Degree          Other Italian university
# 10        Italy     Master's Degree                  LUISS university
# 11        Italia    Master's Degree                  LUISS university
# 12        Italia    Master's Degree                  LUISS university
# 13        Italia    Master's Degree          Other Italian university
# 14        Italia    Master's Degree          Other Italian university
# 15        Italia    Master's Degree          Other Italian university
# 16        Italia    Master's Degree  University abroad (not in Italy)
# 17       Italia     Master's Degree          Other Italian university
# 18        Italia    Master's Degree          Other Italian university
# 19        Italia    Master's Degree          Other Italian university
# 20        italia    Master's Degree                  LUISS university
# 21        Milano    Master's Degree          Other Italian university
# 22         Italy    Master's Degree                  LUISS university
# 23        Italia    Master's Degree          Other Italian university
# 24        Italia    Master's Degree          Other Italian university
# 25        Italia    Master's Degree          Other Italian university
# 26        Italia  Bachelor's Degree          Other Italian university
# 27       Italia                 MBA          Other Italian university
# 29        Italia  Bachelor's Degree          Other Italian university
# 30       Vietnam  Bachelor's Degree          Other Italian university
# 31        italia  Bachelor's Degree          Other Italian university
# 32          Roma        High school          Other Italian university
# 33        Italia  Bachelor's Degree          Other Italian university
# 34        Italia  Bachelor's Degree          Other Italian university
# 35       Italia     Master's Degree          Other Italian university
# 36       Milano   Bachelor's Degree          Other Italian university
# 37       Italia   Bachelor's Degree          Other Italian university
# 38        Italia  Bachelor's Degree          Other Italian university
# 39       Italia   Bachelor's Degree          Other Italian university
# 40       Italia         High school          Other Italian university
# 41        Italia  Bachelor's Degree          Other Italian university
# 42  Italia, Roma    Master's Degree                  LUISS university
# 43        Italia  Bachelor's Degree          Other Italian university
# 44          Roma    Master's Degree          Other Italian university
# 45        Italia    Master's Degree          Other Italian university
# 46        Italia    Master's Degree                  LUISS university
# 48        Italia    Master's Degree          Other Italian university
# 49        Italia  Bachelor's Degree          Other Italian university
# 50        Italia  Bachelor's Degree          Other Italian university
# 51       Italia         High school          Other Italian university
# 52       Italia   Bachelor's Degree          Other Italian university
#
#                                        Academic field  \
# 0                   Economic and Statistical Sciences
# 1                   Mathematical and Computer Science
# 2                       Political and Social Sciences
# 3                              Communication Sciences
# 4                   Economic and Statistical Sciences
# 5                   Economic and Statistical Sciences
# 6                   Economic and Statistical Sciences
# 7   Historical, Philosophical, Educational and Psy...
# 8                   Mathematical and Computer Science
# 9                              Communication Sciences
# 10                  Economic and Statistical Sciences
# 11                  Economic and Statistical Sciences
# 12                  Economic and Statistical Sciences
# 13             Industrial and Information Engineering
# 14                  Economic and Statistical Sciences
# 15                  Economic and Statistical Sciences
# 16                  Economic and Statistical Sciences
# 17                      Political and Social Sciences
# 18                      Political and Social Sciences
# 19             Industrial and Information Engineering
# 20                  Mathematical and Computer Science
# 21                  Economic and Statistical Sciences
# 22                  Mathematical and Computer Science
# 23                      Political and Social Sciences
# 24                  Economic and Statistical Sciences
# 25                                   Chemical Science
# 26                                     Legal Sciences
# 27                                     Legal Sciences
# 29                                   Physical Science
# 30                                     Legal Sciences
# 31                  Economic and Statistical Sciences
# 32         Civil Engineering, Architecture and Design
# 33  Historical, Philosophical, Educational and Psy...
# 34                  Economic and Statistical Sciences
# 35  Historical, Philosophical, Educational and Psy...
# 36                             Communication Sciences
# 37  Historical, Philosophical, Educational and Psy...
# 38             Industrial and Information Engineering
# 39  Historical, Philosophical, Educational and Psy...
# 40                                     Legal Sciences
# 41                                   Chemical Science
# 42                  Economic and Statistical Sciences
# 43  Historical, Philosophical, Educational and Psy...
# 44                  Economic and Statistical Sciences
# 45                  Economic and Statistical Sciences
# 46                  Economic and Statistical Sciences
# 48                      Political and Social Sciences
# 49                                    Medical Science
# 50                                   Physical Science
# 51                  Economic and Statistical Sciences
# 52         Civil Engineering, Architecture and Design
#
#                                              Thoughts
# 0   Se integrata con giudizio, può diventare uno s...
# 1    It is important to understand how to use it t...
# 2   Penso che sarà uno strumento molto utilizzato,...
# 3   L’IA generativa è sicuramente uno strumento mo...
# 4   Se usata correttamente e strategicamente sarà ...
# 5   Credo bisogna trovare il giusto equilibrio nel...
# 6   Bisogna utilizzarla con intelligenza, non pens...
# 7   Credo che l'intelligenza artificiale debba ess...
# 8   Il rapporto umano è indispensabile: l'IA deve ...
# 9   A mio modo di vedere, l’IA può essere un’aiuto...
# 10  If students learn how to use it with the brain...
# 11                                           Positivo
# 12                                                  .
# 13  Penso che possa essere un'ottimo strumento che...
# 14  Credo che la qualità delle informazioni possa ...
# 15  Sicuramente è un grande passo in avanti per la...
# 16  Andrebbe integrata in modo che gli studenti im...
# 17  L’IA sarà sicuramente parte dell’istruzione de...
# 18  Credo che possa portare dinamicità e innovazio...
# 19  Spero che docenti e genitori siano in grado di...
# 20  È un grande strumento per lo sviluppo ed il mi...
# 21  La cooperazione e l’integrazione dello strumen...
# 22                                                 .
# 23  Penso che l'integrazione delle tecnologie sia ...
# 24  Penso che nella giusta misura l'AI possa esser...
# 25                                                  -
# 26    Penso che sia un percorso quasi naturale ormai.
# 27  Potrebbe aiutare a creare un'istruzione più in...
# 29  eliminano le restrizioni di tempo e spazio, co...
# 30  Let's say it will be fascinating with the posi...
# 31  confido molto nell’IA, ha un grande potenziale...
# 32  Lavorando in un campo molto tecnologico potreb...
# 33  Se gestite bene e utilizzate con cura possono ...
# 34  Penso che l’intelligenza artificiale non possa...
# 35  Potrebbe essere utile se integrata in maniera ...
# 36                                                  .
# 37  Potrebbe essere un buon metodo di apprendiment...
# 38  Penso che possa essere un vantaggio sotto cert...
# 39  Sappiamo ancora troppo poco per poterla\nutili...
# 40                                                \n.
# 41                                      Sono a favore
# 42  Penso che sia utile utilizzare l’IA come strum...
# 43  puó portare molto vantaggi, ma deve esserci se...
# 44  che deve rimanere un’integrazione e non una so...
# 45                               positiva a riguardo
# 46  Futuro affascinante e potenzialmente positivo ...
# 48  Può rendere possibile l' Accesso per tutti ma ...
# 49  Non l'ho mai usata quindi non sono molto infor...
# 50  L'IA non deve rimpiazzare gli insegnanti, ma p...
# 51                 Può essere un'arma a doppio taglio
# 52  Penso sia importante per lo sviluppo delle att...
#
# [51 rows x 89 columns]

# %%
df['Home country'].unique()
# Out:
# array(['Italia', 'ITALY', 'Italia ', 'Roma', 'Italy ', 'italia', 'Milano',
#        'Italy', 'Vietnam', 'Milano ', 'Italia, Roma'], dtype=object)

# %%
# Map the answers to specific countries.
map_answer_country = {
'ROMA': 'ITALY',
'MILANO': 'ITALY',
'ITALIA, ROMA': 'ITALY',
'ITALIA': 'ITALY',
'ITALY': 'ITALY'
}

def change_with_country(country):
    country = country.strip().upper()
    return map_answer_country.get(country, country)

df['Home country'] = df['Home country'].apply(change_with_country)

# %%
df ['Home country'].unique()
# Out:
# array(['ITALY', 'VIETNAM'], dtype=object)

# %%
# Compute frequency for personal information columns.
personal_information_columns = ['Age', 'Gender', 'Home country', 'Level of education', 'University', 'Academic field']

value_counts = {col: df[col].value_counts() for col in personal_information_columns}

for col, counts in value_counts.items():
    print(counts)
    print("\n")
# Out:
# Age
# 23-26    31
# 18-22    17
# 27-30     3
# Name: count, dtype: int64
#
#
# Gender
# Female    34
# Male      17
# Name: count, dtype: int64
#
#
# Home country
# ITALY      50
# VIETNAM     1
# Name: count, dtype: int64
#
#
# Level of education
# Master's Degree      30
# Bachelor's Degree    17
# High school           3
# MBA                   1
# Name: count, dtype: int64
#
#
# University
# Other Italian university            40
# LUISS university                    10
# University abroad (not in Italy)     1
# Name: count, dtype: int64
#
#
# Academic field
# Economic and Statistical Sciences                                    19
# Historical, Philosophical, Educational and Psychological Sciences     6
# Political and Social Sciences                                         5
# Mathematical and Computer Science                                     4
# Legal Sciences                                                        4
# Communication Sciences                                                3
# Industrial and Information Engineering                                3
# Chemical Science                                                      2
# Physical Science                                                      2
# Civil Engineering, Architecture and Design                            2
# Medical Science                                                       1
# Name: count, dtype: int64
